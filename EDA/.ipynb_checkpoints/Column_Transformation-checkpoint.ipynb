# %% [markdown]
# ### <span style="color: green"> Column Transformation </span>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("ESD.xlsx")   #ESD data set
df
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
df.columns
# Out:
# Index(['EEID', 'Full Name', 'Job Title', 'Department', 'Business Unit',
#        'Gender', 'Ethnicity', 'Age', 'Hire Date', 'Annual Salary', 'Bonus %',
#        'Country', 'City', 'Exit Date'],
#       dtype='object')

# %%
df.loc[(df["Bonus %"]) > 0, "Get Bonus"] = "Bonus"
df.loc[(df["Bonus %"]) == 0, "Get Bonus"] = "No Bonus"
df
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
df.columns
# Out:
# Index(['EEID', 'Full Name', 'Job Title', 'Department', 'Business Unit',
#        'Gender', 'Ethnicity', 'Age', 'Hire Date', 'Annual Salary', 'Bonus %',
#        'Country', 'City', 'Exit Date', 'Get Bonus'],
#       dtype='object')

# %%
df["Get Bonus"].value_counts()
# Out:
# Get Bonus
# No Bonus    525
# Bonus       475
# Name: count, dtype: int64

# %%
df1 = pd.read_excel("practice.xlsx")      #practice data set
display(df1)
# Out:
#   First name  Last name  Salary EEID
# 0      rohit     sharma   20000   E1
# 1      ratan       tata   40000   E2
# 2      virat      kohli   25000   E7
# 3     sachin  tendulkar   60000   E8
# 4      anand   mahindra   33000   E4
# 5     kartik      aryan   45000   E5

# %%
df1.columns
# Out:
# Index(['First name', 'Last name', 'Salary', 'EEID'], dtype='object')

# %%
df1["Full Name"] = df1['First name']+' '+df1['Last name']
df1
# Out:
#   First name  Last name  Salary EEID         Full Name
# 0      rohit     sharma   20000   E1      rohit sharma
# 1      ratan       tata   40000   E2        ratan tata
# 2      virat      kohli   25000   E7       virat kohli
# 3     sachin  tendulkar   60000   E8  sachin tendulkar
# 4      anand   mahindra   33000   E4    anand mahindra
# 5     kartik      aryan   45000   E5      kartik aryan

# %%
df1["Full Name"] = df1['First name'].str.capitalize()+' '+df1['Last name'].str.capitalize()
df1
# Out:
#   First name  Last name  Salary EEID         Full Name
# 0      rohit     sharma   20000   E1      Rohit Sharma
# 1      ratan       tata   40000   E2        Ratan Tata
# 2      virat      kohli   25000   E7       Virat Kohli
# 3     sachin  tendulkar   60000   E8  Sachin Tendulkar
# 4      anand   mahindra   33000   E4    Anand Mahindra
# 5     kartik      aryan   45000   E5      Kartik Aryan

# %%
df1["Bonus"] = df1["Salary"]*0.10
df1
# Out:
#   First name  Last name  Salary EEID         Full Name   Bonus
# 0      rohit     sharma   20000   E1      Rohit Sharma  2000.0
# 1      ratan       tata   40000   E2        Ratan Tata  4000.0
# 2      virat      kohli   25000   E7       Virat Kohli  2500.0
# 3     sachin  tendulkar   60000   E8  Sachin Tendulkar  6000.0
# 4      anand   mahindra   33000   E4    Anand Mahindra  3300.0
# 5     kartik      aryan   45000   E5      Kartik Aryan  4500.0

# %%
df1.rename(columns={'EEID':"Emp-ID", "First name": "First Name", "Last name": "Last Name"}, inplace = True)
df1
# Out:
#   First Name  Last Name  Salary Emp-ID         Full Name   Bonus
# 0      rohit     sharma   20000     E1      Rohit Sharma  2000.0
# 1      ratan       tata   40000     E2        Ratan Tata  4000.0
# 2      virat      kohli   25000     E7       Virat Kohli  2500.0
# 3     sachin  tendulkar   60000     E8  Sachin Tendulkar  6000.0
# 4      anand   mahindra   33000     E4    Anand Mahindra  3300.0
# 5     kartik      aryan   45000     E5      Kartik Aryan  4500.0

# %%
df
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
df.rename(columns={"Hire Date": "Hire-Date", "Exit Date": "Exit-Date"}, inplace = True)
df
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire-Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...
