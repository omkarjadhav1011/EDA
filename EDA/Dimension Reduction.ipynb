# %% [markdown]
# ## Dimension Reduction

# %%
import pandas as pd
import numpy as np
from datetime import date, datetime

# %%
df_student = pd.read_excel('Data/students_adaptability_level_online_education.xlsx')
df_student.head()
# Out:
#   Gender                  Age Education Level Institution Type IT Student  \
# 0    Boy                21-25      University   Non Government         No
# 1   Girl                21-25      University   Non Government         No
# 2   Girl                16-20         College       Government         No
# 3   Girl  2024-11-15 00:00:00          School   Non Government         No
# 4   Girl                16-20          School   Non Government         No
#
#   Location Load-shedding Financial Condition Internet Type Network Type  \
# 0      Yes           Low                 Mid          Wifi           4G
# 1      Yes          High                 Mid   Mobile Data           4G
# 2      Yes           Low                 Mid          Wifi           4G
# 3      Yes           Low                 Mid   Mobile Data           4G
# 4      Yes           Low                Poor   Mobile Data           3G
#
#         Class Duration Self Lms  Device Adaptivity Level
# ...

# %%
df_student.shape
# Out:
# (1205, 14)

# %%
df_student.isna().sum()
# Out:
# Gender                 0
# Age                    0
# Education Level        0
# Institution Type       0
# IT Student             0
# Location               0
# Load-shedding          0
# Financial Condition    0
# Internet Type          0
# Network Type           0
# Class Duration         0
# Self Lms               0
# Device                 0
# Adaptivity Level       0
# dtype: int64

# %%
df_student.iloc[1]
# Out:
# Gender                                Girl
# Age                                  21-25
# Education Level                 University
# Institution Type            Non Government
# IT Student                              No
# Location                               Yes
# Load-shedding                         High
# Financial Condition                    Mid
# Internet Type                  Mobile Data
# Network Type                            4G
# Class Duration         2024-01-03 00:00:00
# Self Lms                               Yes
# Device                              Mobile
# Adaptivity Level                  Moderate
# Name: 1, dtype: object

# %%
df_student[(df_student['Education Level'] =='School' )& (df_student['Institution Type']=='Government') & (df_student['Class Duration']!= 0) & (df_student['Device']!= np.nan)]
# Out:
#      Gender                  Age Education Level Institution Type IT Student  \
# 39     Girl  2024-11-15 00:00:00          School       Government         No
# 68     Girl  2024-11-15 00:00:00          School       Government         No
# 97     Girl  2024-11-15 00:00:00          School       Government         No
# 105     Boy  2024-11-15 00:00:00          School       Government         No
# 128    Girl  2024-11-15 00:00:00          School       Government         No
# ...     ...                  ...             ...              ...        ...
# 1122    Boy                16-20          School       Government         No
# 1125   Girl  2024-11-15 00:00:00          School       Government         No
# 1142   Girl                16-20          School       Government         No
# 1151   Girl  2024-11-15 00:00:00          School       Government         No
# 1161   Girl  2024-11-15 00:00:00          School       Government         No
#
# ...

# %%
df_student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1205 entries, 0 to 1204
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Gender               1205 non-null   object
#  1   Age                  1205 non-null   object
#  2   Education Level      1205 non-null   object
#  3   Institution Type     1205 non-null   object
#  4   IT Student           1205 non-null   object
#  5   Location             1205 non-null   object
#  6   Load-shedding        1205 non-null   object
#  7   Financial Condition  1205 non-null   object
#  8   Internet Type        1205 non-null   object
#  9   Network Type         1205 non-null   object
#  10  Class Duration       1205 non-null   object
#  11  Self Lms             1205 non-null   object
#  12  Device               1205 non-null   object
#  13  Adaptivity Level     1205 non-null   object
# dtypes: object(14)
# memory usage: 131.9+ KB

# %%
df_student['Class Duration']
# Out:
# 0       2024-03-06 00:00:00
# 1       2024-01-03 00:00:00
# 2       2024-01-03 00:00:00
# 3       2024-01-03 00:00:00
# 4                         0
#                ...
# 1200    2024-01-03 00:00:00
# 1201    2024-03-06 00:00:00
# 1202    2024-01-03 00:00:00
# 1203    2022-01-03 00:00:00
# 1204    2024-01-03 00:00:00
# Name: Class Duration, Length: 1205, dtype: object

# %%
df_student.loc[datetime.strptime(df_student['Class Duration'].to_datetime().strftime('%Y'), '%Y'),year]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2264\3047122889.py in ?()
# ----> 1 df_student.loc[datetime.strptime(df_student['Class Duration'].to_datetime().strftime('%Y'), '%Y'),year]
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'to_datetime'
